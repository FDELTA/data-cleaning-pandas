# %%
import pandas as pd

# %%
df = pd.read_csv('../../data-cleaning-pandas/attacks.csv',encoding='latin-1')
display(df.head())
print(df.shape)
#let's start from the last row
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
list(df.isnull().sum().sort_values(ascending=False).items())
# Out:
# [('Unnamed: 22', 25722),
#  ('Unnamed: 23', 25721),
#  ('Time', 22775),
#  ('Species ', 22259),
#  ('Age', 22252),
#  ('Sex ', 19986),
#  ('Activity', 19965),
#  ('Location', 19961),
#  ('Fatal (Y/N)', 19960),
#  ('Area', 19876),
#  ('Name', 19631),
#  ('Country', 19471),
#  ('Injury', 19449),
#  ('Investigator or Source', 19438),
#  ('Type', 19425),
#  ('Year', 19423),
#  ('href formula', 19422),
#  ('pdf', 19421),
#  ('href', 19421),
#  ('Case Number.1', 19421),
#  ('Case Number.2', 19421),
#  ('Date', 19421),
#  ('original order', 19414),
#  ('Case Number', 17021)]

# %%
#Once you noticed that "Unamed" columns are mostly empty proceed to find out what do they containabs
df["Unnamed: 22"].fillna(0, inplace=True)
[x for x in df['Unnamed: 22'] if x != 0]
#This returns the only value that is not null in "Unnamed: 22"
# Out:
# ['stopped here']

# %%
#This returns the values that aren't null in "Unnamed: 23"
df['Unnamed: 23'].fillna(0, inplace=True)
[y for y in df['Unnamed: 23'] if y!=0]
# Out:
# ['Teramo', 'change filename']

# %%
#It doesn't contain any valuable information, so it can be deleted
df1 = df.drop(['Unnamed: 22', 'Unnamed: 23'], axis = 1)

# %%
#if we look at head values of columns "Case Number.1" "Case Number" and "Case Number.2" they look the same so let's find out if they are duplicates
df['Case Number.1'].equals(df['Case Number'].equals(df['Case Number.2'])) or df['Case Number.1'].equals(df['Case Number.2'])
# Out:
# False

# %%
#apparently they are not the same columns so let's look how many differences do they have
df['Case Number.1'].isin(df['Case Number.2']).value_counts()
#It results not to be different enough to keep both as they are not adding 'Extra value' to the analysis
# Out:
# True     25704
# False       19
# Name: Case Number.1, dtype: int64

# %%
df['Case Number'].isin(df['Case Number.1']).value_counts()
# Out:
# True     23299
# False     2424
# Name: Case Number, dtype: int64

# %%
#Columns 'Case' seems to the same column with slightly little differences and no 'value information' for deeper analysis
df2 = df1.drop(columns=['Case Number.1','Case Number.2'])
display(df2.head())
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
#Same procedure for href

# %%
df['href'].equals(df['href formula'])
# Out:
# False

# %%
df['href'].isin(df['href formula']).value_counts()
# Out:
# True     25666
# False       57
# Name: href, dtype: int64

# %%
df3 = df2.drop(columns = ['href'])
display(df3.head())
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
#Also original order is the past index, not useful anymore
df4 = df3.drop(columns = ['original order'])

# %%
#now I'll got directly to compare 'Case Number' with 'Date' because they apparantely tell the same but with different formats
#First I need both columns in the same format in order to compare it
s = df4["Case Number"].str.split(".", n = 2, expand = True)
df4['Year_'] = s[0]
df4['Month'] = s[1]
df4['Day'] = s[2]

# %%
df4['Year_'].isin(df4['Year']).value_counts()
# Out:
# True     17021
# False     8702
# Name: Year_, dtype: int64

# %%
#Big numbers Year == Year_ so we'll procced to drop Year
df5 = df4.drop(columns=['Year'])

# %%
z = df5["Date"].str.split("-", n = 2, expand = True)
df5['Year_1'] = s[0]
df5['Month1'] = s[1]
df5['Day1'] = s[2]

# %%
display(df5)
# Out:
#       Case Number         Date        Type    Country             Area  \
# 0      2018.06.25  25-Jun-2018     Boating        USA       California
# 1      2018.06.18  18-Jun-2018  Unprovoked        USA          Georgia
# 2      2018.06.09  09-Jun-2018     Invalid        USA           Hawaii
# 3      2018.06.08  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4      2018.06.04  04-Jun-2018    Provoked     MEXICO           Colima
# ...           ...          ...         ...        ...              ...
# 25718         NaN          NaN         NaN        NaN              NaN
# 25719         NaN          NaN         NaN        NaN              NaN
# 25720         NaN          NaN         NaN        NaN              NaN
# 25721         NaN          NaN         NaN        NaN              NaN
# 25722          xx          NaN         NaN        NaN              NaN
#
#                              Location     Activity             Name Sex   Age  \
# ...

# %%
df4['Year_'].isin(df4['Year_1']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-cc6ba24390b1> in <module>
# ...

# %%
df4['Month'].isin(df4['Month1']).value_counts()

# %%
df4['Day'].isin(df4['Day1']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-dd7342be4c28> in <module>
# ...

# %%
#as we can see 'Date' and 'Case Number' are almost equal
df6 = df5.drop(columns=['Case Number','Day','Month','Year_'])
df6['Year'] = df6['Year_1']
df6 = df5.drop(columns=['Case Number','Day1','Month1','Year_1','Day','Month'])

# %%
display(df6)
# Out:
#               Date        Type    Country             Area  \
# 0      25-Jun-2018     Boating        USA       California
# 1      18-Jun-2018  Unprovoked        USA          Georgia
# 2      09-Jun-2018     Invalid        USA           Hawaii
# 3      08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4      04-Jun-2018    Provoked     MEXICO           Colima
# ...            ...         ...        ...              ...
# 25718          NaN         NaN        NaN              NaN
# 25719          NaN         NaN        NaN              NaN
# 25720          NaN         NaN        NaN              NaN
# 25721          NaN         NaN        NaN              NaN
# 25722          NaN         NaN        NaN              NaN
#
#                              Location     Activity             Name Sex   Age  \
# 0         Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1      St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# ...

# %%
df6.isnull().sum()
# Out:
# Date                      19421
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# Year_                     17021
# dtype: int64

# %%
#Time is also not useful for the study and is mostly empty
df6 = df6.drop(columns=['Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-5d4c1b8c9ca9> in <module>
#       1 #Time is also not useful for the study and is mostly empty
# ----> 2 df6 = df6.drop(columns=['Time'])
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4155                 weight  1.0     0.8
#    4156         """
# -> 4157         return super().drop(
#    4158             labels=labels,
#    4159             axis=axis,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
df6 = df6.dropna(how='all')

# %%
df6.isnull().sum()
# Out:
# Date                      2401
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href formula              2402
# Year_                        1
# dtype: int64

# %%
#Year_ is distorsting the data set as it's very clean. I'll eliminate it temporarly to see if I can clean it a bit more.
df7 = df6.drop(columns=['Year_'])
df7 = df7.dropna(how='all')

# %%
display(df7)
# Out:
#              Date        Type             Country               Area  \
# 0     25-Jun-2018     Boating                 USA         California
# 1     18-Jun-2018  Unprovoked                 USA            Georgia
# 2     09-Jun-2018     Invalid                 USA             Hawaii
# 3     08-Jun-2018  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018    Provoked              MEXICO             Colima
# ...           ...         ...                 ...                ...
# 6297  Before 1903  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905  Unprovoked                 USA     North Carolina
# 6300    1883-1889  Unprovoked              PANAMA                NaN
# 6301    1845-1853  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0             Oceanside, San Diego County      Paddling
# ...

# %%
df7.isnull().sum()
#Now the dataframe is clean enough to start with the hypothesis
# Out:
# Date                         0
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href formula                 1
# dtype: int64

# %%
# %store df7
# Out:
# Stored 'df7' (DataFrame)
